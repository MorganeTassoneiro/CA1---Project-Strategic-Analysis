# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#excel file 
file_path = r"C:\Users\morga\OneDrive\Documents\GitHub\Project-Strategic-Analysis\CA1---Project-Strategic-Analysis\sales-data.xlsx"
df = pd.read_excel(file_path, sheet_name="Sheet1")

# %%
# to avoid errors
df.columns = df.columns.str.strip()

# datetime format for proper analysis
df['Date'] = pd.to_datetime(df['Date'])

# filter data to start from Tuesday (11/02)
df_main = df[df['Date'] >= '2025-02-11']

# %%
# ---- SALES TREND OVER TIME ----
sales_trend = df_main.groupby('Date')['Sales'].sum()
plt.figure(figsize=(12, 6))
plt.plot(sales_trend.index, sales_trend.values, marker='o', linestyle='-', linewidth=2, color='blue')
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.title("Sales Trend Over Time (Starting Tuesday 11/02)")
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %%
# ---- BEST-SELLING MEALS ----
meal_sales = df_main.groupby('MealName')['Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
meal_sales.head(10).plot(kind='bar', color='blue', edgecolor='black')
plt.xlabel("Meal Name")
plt.ylabel("Total Sales")
plt.title("Top 10 Best Selling Meals")
plt.xticks(rotation=75)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
## ---- SLOW-MOVING MEALS ---- #############  REVIEW THIS   #############
plt.figure(figsize=(12, 6))
meal_sales.tail(10).plot(kind='bar', color='RED', edgecolor='black')
plt.xlabel("Meal Name")
plt.ylabel("Total Sales")
plt.title("Top 10 Slow Moving Meals")
plt.xticks(rotation=75)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# ---- MOST WASTED MEALS ----
meal_waste = df_main.groupby('MealName')['Waste'].sum().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
meal_waste.head(10).plot(kind='bar', color='red', edgecolor='black')
plt.xlabel("Meal Name")
plt.ylabel("Total Waste")
plt.title("Top 10 Most Wasted Meals")
plt.xticks(rotation=75)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Fastest Selling Meals

#  FilterING meals that were received and sold on the same day
fast_turnover = df[df['Received'] > 0].copy()

# calculate the sell-out ratio (sales/received)
fast_turnover['Sell_Out_Ratio'] = fast_turnover['Sales'] / fast_turnover['Received']

# average sell-out ratio per meal
fastest_turnover_meals = fast_turnover.groupby('MealName')['Sell_Out_Ratio'].mean().sort_values(ascending=False)


#  Bar Chart for top 10 meals that sell out quickly
plt.figure(figsize=(12, 6))
fastest_turnover_meals.head(10).plot(kind='bar', color='green', edgecolor='black')
plt.xlabel("Meal Name")
plt.ylabel("Sell-Out Ratio (Sales/Received)")
plt.title("Top 10 Fastest Selling Meals")
plt.xticks(rotation=75)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Sales WEEKDAY VS WEEKEND SALES

# %%
#TOP 10 MEALS THAT SELL TOGETHER MOST OFTEN

# %%
# MEALS THAT ARE NOT THERE FOR MONDAY AS THERE IS NO DELIVERY
