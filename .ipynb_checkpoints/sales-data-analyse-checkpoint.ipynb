# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
#excel file 
file_path = r"C:\Users\morga\OneDrive\Documents\GitHub\Project-Strategic-Analysis\CA1---Project-Strategic-Analysis\sales-data.xlsx"
df = pd.read_excel(file_path, sheet_name="Sheet1")

# %%
# clean
df.columns = df.columns.str.strip()

#datetime format 
df["Date"] = pd.to_datetime(df["Date"])

# relevant columns
df = df[["DayOfWeek", "Date", "MealName", "Sales", "Received", "Waste", "InitialStock", "FinalStock"]]

# %% [markdown]
# ## SALES TREND OVER TIME
#
#
# * Shows how daily sales change over time;
# * Helps identify peak sales days and slow periods;
# * Useful for predicting demand.

# %%
plt.figure(figsize=(12, 6))
plt.plot(sales_trend.index, sales_trend.values, marker='o', linestyle='-', linewidth=2, color='blue')

plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.title("Sales Trend Over Time")
plt.xticks(rotation=45)

# x-ticks to show every day
plt.xticks(sales_trend.index, sales_trend.index.strftime('%Y-%m-%d'), rotation=90, fontsize=8) 

plt.grid(True)
plt.show()

# %% [markdown]
# * Identify that sales increase on friday;
# * Spot low-demand days for adjustments.

# %% [markdown]
# ## BEST-SELLING MEALS
#
# * Shows which meals sell the most;
# * Helps in stock planning  - increase stock for top sellers;
# * Useful if I like to deciding which meals to promote more.

# %%
# best selling Meals
best_sellers = df.groupby('MealName')['Sales'].sum().sort_values(ascending=False).head(15)

# plot
plt.figure(figsize=(12, 6))
best_sellers.plot(kind='bar', color='green', edgecolor='black')
plt.xlabel("Meal Name")
plt.ylabel("Total Sales")
plt.title("Top 15 Best-Selling Meals")
plt.xticks(rotation=75)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# * Know which meals need more stock;
# * Decide if any meal should have a higher price.

# %% [markdown]
# ## STOCK NEED vs. SALES
#
# * Comparing stock received vs. sales to know if stock is too high or too low.
# * Helps decide which meals need increased or decreased stock.

# %%
# Ensure the stock vs. sales comparison uses correct stock columns
stock_vs_sales = df.groupby("MealName").agg({
    "Sales": "sum",
    "Received": "sum",
    "InitialStock": "max",  # Get starting stock level
    "FinalStock": "min"     # Get final stock level
}).sort_values(by="Sales", ascending=False)

# ✅ Fixing Bar Chart Plot (Using InitialStock and FinalStock)
plt.figure(figsize=(12, 6))
stock_vs_sales[["Sales", "Received"]].head(15).plot(kind="bar", width=0.8, edgecolor="black")
plt.xlabel("Meal Name")
plt.ylabel("Count")
plt.title("Stock Received vs. Sales (Top 10 Meals)")
plt.xticks(rotation=75)
plt.legend(["Sales", "Stock Received"])
plt.show()

# %% [markdown]
# * If sales are higher than stock, means a need to increase stock;
# * If stock is too high compared to sales, reduce orders.

# %% [markdown]
# ## Meals That Ran Out on Friday and Saturday
#
# * Highlights meals that sold out before the weekend (busiest days);

# %%
missing_meals = df[
    (df['DayOfWeek'].isin(['Friday', 'Saturday'])) &  
    (df['StockOnShelf'] == 0) &  
    (df['Received'] == 0)  
]

# counting meals that sold out
missing_meal_counts = missing_meals['MealName'].value_counts()

# Plot
plt.figure(figsize=(12, 6))
missing_meal_counts.plot(kind='bar', color='red', edgecolor='black')
plt.xlabel("Meal Name")
plt.ylabel("Times Out of Stock")
plt.title("Meals Missing on Friday & Saturday")
plt.xticks(rotation=75)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Get all Sundays in the dataset
sundays = df[df["DayOfWeek"] == "Sunday"]["Date"].unique()

# Identify meals that had zero FinalStock before all Sundays
consistent_stockout_meals = df[df["Date"].isin(sundays) & (df["FinalStock"] == 0)]
consistent_stockout_counts = consistent_stockout_meals.groupby("MealName")["Date"].nunique().reset_index()

# ✅ Only keep meals missing for ALL Sundays
meals_missing_all_sundays = consistent_stockout_counts[consistent_stockout_counts["Date"] == len(sundays)]

# Display results
print("Meals that were out of stock before all Sundays:")
print(meals_missing_all_sundays)
# Out:
# Meals that were out of stock before all Sundays:
#                            MealName  Date
# 0              AUBERGINE PARMIGIANA     4
# 3                BEEF STROGONOFF SP     4
# 4                        BROWN RICE     4
# 9                  CHILLI CON CARNE     4
# 10              CHILLI CON CARNE SP     4
# 13           CREAMY CHICKEN MARSALA     4
# 15         CREAMY MASH POTATO LARGE     4
# 16         CREAMY MASH POTATO SMALL     4
# 17       CREAMY MUSHROOM PASTA BAKE     4
# 18           CRISPY CHICKEN GOUJONS     4
# 22          GARLICKY PRAWN LINGUINE     4
# 23             GOODFELLAS MEATBALLS     4
# 24  HERB & HONEY ROAST ROOT VEGGIES     4
# 25                   HERBY POTATOES     4
# 26             HOMEMADE COTTAGE PIE     4
# 27                 JUNIORS FISH PIE     4
# 28             LASAGNE TRADIZIONALE     4
# 29        LASAGNE TRADIZIONALE 950G     4
# 31              RAGÚ ALLA BOLOGNESE     4
# 33                         ROASTIES     4
# 35                  SEASONAL GREENS     4
# 37              SPAGHETTI BOLOGNESE     4
# 40           THAI RED CHICKEN CURRY     4

# %% [markdown]
# * Helps adjust stock levels to prevent shortages.

# %% [markdown]
# ## Waste Analysis
# * meals that had the most waste;

# %%
waste_analysis = df.groupby('MealName')['Waste'].sum().sort_values(ascending=False).head(10)

# plot
plt.figure(figsize=(12, 6))
waste_analysis.plot(kind='bar', color='orange', edgecolor='black')
plt.xlabel("Meal Name")
plt.ylabel("Total Waste")
plt.title("Top 10 Most Wasted Meals")
plt.xticks(rotation=75)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
